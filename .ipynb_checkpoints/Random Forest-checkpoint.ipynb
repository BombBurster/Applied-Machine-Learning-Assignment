# %%
import numpy as np
import matplotlib.pyplot as plt
#Prevent scientific notation
np.set_printoptions(suppress=True)
import pandas as pd

# %%
#Load the dataset and seperate the target colum
df = pd.read_csv('Absenteeism/Absenteeism_at_work.csv', delimiter=';')
#df = pd.read_csv('Absenteeism/Absenteeism_at_work_editted.csv')
#df = df.iloc[:20,:]
X = df.iloc[:,:-1].to_numpy()
y = df.iloc[:,-1].to_numpy()
df
# Out:
#      ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 0    11                  26                 7                3        1
# 1    36                   0                 7                3        1
# 2     3                  23                 7                4        1
# 3     7                   7                 7                5        1
# 4    11                  23                 7                5        1
# ..   ..                 ...               ...              ...      ...
# 735  11                  14                 7                3        1
# 736   1                  11                 7                3        1
# 737   4                   0                 0                3        1
# 738   8                   0                 0                4        2
# 739  35                   0                 0                6        3
#
#      Transportation expense  Distance from Residence to Work  Service time  \
# 0                       289                               36            13
# 1                       118                               13            18
# 2                       179                               51            18
# 3                       279                                5            14
# 4                       289                               36            13
# ..                      ...                              ...           ...
# 735                     289                               36            13
# 736                     235                               11            14
# 737                     118                               14            13
# 738                     231                               35            14
# 739                     179                               45            14
#
#      Age  Work load Average/day   ...  Disciplinary failure  Education  Son  \
# 0     33                 239.554  ...                     0          1    2
# 1     50                 239.554  ...                     1          1    1
# 2     38                 239.554  ...                     0          1    0
# 3     39                 239.554  ...                     0          1    2
# 4     33                 239.554  ...                     0          1    2
# ..   ...                     ...  ...                   ...        ...  ...
# 735   33                 264.604  ...                     0          1    2
# 736   37                 264.604  ...                     0          3    1
# 737   40                 271.219  ...                     0          1    1
# 738   39                 271.219  ...                     0          1    2
# 739   53                 271.219  ...                     0          1    1
#
#      Social drinker  Social smoker  Pet  Weight  Height  Body mass index  \
# 0                 1              0    1      90     172               30
# 1                 1              0    0      98     178               31
# 2                 1              0    0      89     170               31
# 3                 1              1    0      68     168               24
# 4                 1              0    1      90     172               30
# ..              ...            ...  ...     ...     ...              ...
# 735               1              0    1      90     172               30
# 736               0              0    1      88     172               29
# 737               1              0    8      98     170               34
# 738               1              0    2     100     170               35
# 739               0              0    1      77     175               25
#
#      Absenteeism time in hours
# 0                            4
# 1                            0
# 2                            2
# 3                            4
# 4                            2
# ..                         ...
# 735                          8
# 736                          4
# 737                          0
# 738                          0
# 739                          0
#
# [740 rows x 21 columns]

# %%
class DecisionTreeRegressor:
    def __init__(self, min_rows=5):
        self.min_rows = min_rows

    #Calculate the residual sum of squares for vector v
    def _calc_rss(self,v):
        v_sorted = np.sort(v)
        len_v = len(v_sorted)
        totals = []
        for i in range(len_v-1):
            mean = np.mean(v_sorted[i:i+1])
            mean_left = np.mean(v_sorted[0:i+1])
            mean_right = np.mean(v_sorted[i+1:len_v])
            rss_left = np.sum((v_sorted[0:i+1]-mean_left) ** 2)
            rss_right = np.sum((v_sorted[i+1:len_v]-mean_right) ** 2)
            totals.append(rss_left + rss_right)
        return v_sorted, np.array(totals)

    #Get the value for the minimum rss
    def _min_rss(self,X):
        vals, rss = self._calc_rss(X)
        minrss = np.min(rss)
        idx = vals[np.where(rss==minrss)][0]
        count = len(X[X==idx])
        return idx,count,minrss

    #Get the feature that produce the best split
    def _best_feature_to_split(self,X):
        feature = None
        cutoff = None
        rss = None
        #Calculate the mean of  the last column (target)
        value = np.mean(X[:,-1])
        #Calculate the min rss for all features
        #Exclude the target column
        for i in range(X.shape[1]-1):
            idx, count, minrss = self._min_rss(X[:,i])
            #Only split the feature if there are different values for the feature
            if (X.shape[0] > count):
                if feature==None:
                    feature = i
                    cutoff = idx
                    rss = minrss
                elif (minrss<rss):
                    feature = i
                    cutoff = idx
                    rss = minrss
        return feature,cutoff,value

    def _split(self,frame):
        left_branch = right_branch = name = None
        feature, cutoff, value = self._best_feature_to_split(frame.to_numpy())
        if feature is not None:
            name = frame.columns[feature]
            left_branch = frame.loc[frame.iloc[:,feature]<=cutoff]
            right_branch = frame.loc[frame.iloc[:,feature]>cutoff]
        return feature, name, cutoff, value, left_branch, right_branch
        
    def fit(self, frame):
        if (frame.shape[0] < self.min_rows):
            return {None}
        feature, name, cutoff, value, left, right = self._split(frame)
        if (feature is None):
            return {None}
        else:
            node = {'feature': feature, 'name': name, 'cutoff': cutoff, 'value': value}
            node['left_node'] = self.fit(left)
            node['right_node'] = self.fit(right)
        self.nodes = node
        return node
    
    def predict(self, X):
        y_pred = []
        for i in range(X.shape[0]):
            y_pred.append(self._run_tree(self.nodes, df.iloc[i,:]))
        return np.array(y_pred, dtype=np.int64)
    
    def _run_tree(self, node, x):
        feature = node['feature']
        name = node['name']
        cutoff = node['cutoff']
        value = node['value']
        left_node = node['left_node']
        right_node = node['right_node']
        if left_node == {None} and right_node == {None}:
            return value
        if x[name]>cutoff:
            if right_node == {None}:
                return value
            else:
                return self._run_tree(right_node,x)
        else:
            if left_node == {None}:
                return value
            else:
                return self._run_tree(left_node,x)
            
    def get_nodes(self):
        return self.nodes

# %%
model = DecisionTreeRegressor()
nodes = model.fit(df)
nodes
# Out:
# {'feature': 11,
#  'name': 'Disciplinary failure',
#  'cutoff': 0.0,
#  'value': 6.924324324324324,
#  'left_node': {'feature': 14,
#   'name': 'Social drinker',
#   'cutoff': 0.0,
#   'value': 7.32,
#   'left_node': {'feature': 15,
#    'name': 'Social smoker',
#    'cutoff': 0.0,
#    'value': 6.182410423452769,
#    'left_node': {'feature': 12,
#     'name': 'Education',
#     'cutoff': 1.0,
#     'value': 6.140287769784172,
#     'left_node': {'feature': 16,
#      'name': 'Pet',
#      'cutoff': 1.0,
#      'value': 6.288043478260869,
#      'left_node': {'feature': 16,
#       'name': 'Pet',
#       'cutoff': 0.0,
#       'value': 7.520833333333333,
#       'left_node': {'feature': 7,
#        'name': 'Service time',
#        'cutoff': 7.0,
#        'value': 6.046875,
#        'left_node': {'feature': 1,
#         'name': 'Reason for absence',
#         'cutoff': 7.0,
#         'value': 3.857142857142857,
#         'left_node': {None},
#         'right_node': {'feature': 4,
#          'name': 'Seasons',
#          'cutoff': 1.0,
#          'value': 3.0,
#          'left_node': {None},
#          'right_node': {None}}},
#        'right_node': {'feature': 0,
#         'name': 'ID',
#         'cutoff': 31.0,
#         'value': 6.315789473684211,
#         'left_node': {None},
#         'right_node': {'feature': 4,
#          'name': 'Seasons',
#          'cutoff': 2.0,
#          'value': 6.254545454545455,
#          'left_node': {'feature': 4,
#           'name': 'Seasons',
#           'cutoff': 1.0,
#           'value': 4.241379310344827,
#           'left_node': {'feature': 2,
#            'name': 'Month of absence',
#            'cutoff': 7.0,
#            'value': 4.357142857142857,
#            'left_node': {'feature': 2,
#             'name': 'Month of absence',
#             'cutoff': 6.0,
#             'value': 4.666666666666667,
#             'left_node': {None},
#             'right_node': {'feature': 10,
#              'name': 'Hit target',
#              'cutoff': 93.0,
#              'value': 5.666666666666667,
#              'left_node': {None},
#              'right_node': {None}}},
#            'right_node': {'feature': 1,
#             'name': 'Reason for absence',
#             'cutoff': 23.0,
#             'value': 3.8,
#             'left_node': {None},
#             'right_node': {None}}},
#           'right_node': {'feature': 2,
#            'name': 'Month of absence',
#            'cutoff': 1.0,
#            'value': 4.133333333333334,
#            'left_node': {'feature': 1,
#             'name': 'Reason for absence',
#             'cutoff': 19.0,
#             'value': 4.0,
#             'left_node': {None},
#             'right_node': {'feature': 3,
#              'name': 'Day of the week',
#              'cutoff': 3.0,
#              'value': 1.7272727272727273,
#              'left_node': {'feature': 3,
#               'name': 'Day of the week',
#               'cutoff': 2.0,
#               'value': 1.5,
#               'left_node': {None},
#               'right_node': {None}},
#              'right_node': {'feature': 3,
#               'name': 'Day of the week',
#               'cutoff': 4.0,
#               'value': 2.0,
#               'left_node': {None},
#               'right_node': {None}}}},
#            'right_node': {None}}},
#          'right_node': {'feature': 4,
#           'name': 'Seasons',
#           'cutoff': 3.0,
#           'value': 8.5,
#           'left_node': {'feature': 2,
#            'name': 'Month of absence',
#            'cutoff': 5.0,
#            'value': 3.8,
#            'left_node': {'feature': 2,
#             'name': 'Month of absence',
#             'cutoff': 4.0,
#             'value': 2.8333333333333335,
#             'left_node': {None},
#             'right_node': {None}},
#            'right_node': {None}},
#           'right_node': {'feature': 2,
#            'name': 'Month of absence',
#            'cutoff': 10.0,
#            'value': 11.4375,
#            'left_node': {'feature': 1,
#             'name': 'Reason for absence',
#             'cutoff': 7.0,
#             'value': 2.6,
#             'left_node': {None},
#             'right_node': {None}},
#            'right_node': {'feature': 2,
#             'name': 'Month of absence',
#             'cutoff': 11.0,
#             'value': 15.454545454545455,
#             'left_node': {'feature': 9,
#              'name': 'Work load Average/day ',
#              'cutoff': 268.519,
#              'value': 5.714285714285714,
#              'left_node': {'feature': 3,
#               'name': 'Day of the week',
#               'cutoff': 3.0,
#               'value': 5.8,
#               'left_node': {None},
#               'right_node': {None}},
#              'right_node': {None}},
#             'right_node': {None}}}}}}},
#       'right_node': {'feature': 7,
#        'name': 'Service time',
#        'cutoff': 14.0,
#        'value': 10.46875,
#        'left_node': {'feature': 0,
#         'name': 'ID',
#         'cutoff': 33.0,
#         'value': 3.0416666666666665,
#         'left_node': {'feature': 4,
#          'name': 'Seasons',
#          'cutoff': 2.0,
#          'value': 3.1739130434782608,
#          'left_node': {'feature': 4,
#           'name': 'Seasons',
#           'cutoff': 1.0,
#           'value': 2.6363636363636362,
#           'left_node': {None},
#           'right_node': {'feature': 2,
#            'name': 'Month of absence',
#            'cutoff': 2.0,
#            'value': 3.2857142857142856,
#            'left_node': {None},
#            'right_node': {'feature': 9,
#             'name': 'Work load Average/day ',
#             'cutoff': 222.196,
#             'value': 2.6,
#             'left_node': {None},
#             'right_node': {None}}}},
#          'right_node': {'feature': 4,
#           'name': 'Seasons',
#           'cutoff': 3.0,
#           'value': 3.6666666666666665,
#           'left_node': {'feature': 2,
#            'name': 'Month of absence',
#            'cutoff': 3.0,
#            'value': 5.0,
#            'left_node': {None},
#            'right_node': {None}},
#           'right_node': {'feature': 2,
#            'name': 'Month of absence',
#            'cutoff': 10.0,
#            'value': 2.7142857142857144,
#            'left_node': {None},
#            'right_node': {None}}}},
#         'right_node': {None}},
#        'right_node': {'feature': 3,
#         'name': 'Day of the week',
#         'cutoff': 3.0,
#         'value': 32.75,
#         'left_node': {'feature': 3,
#          'name': 'Day of the week',
#          'cutoff': 2.0,
#          'value': 50.2,
#          'left_node': {None},
#          'right_node': {None}},
#         'right_node': {None}}}},
#      'right_node': {'feature': 17,
#       'name': 'Weight',
#       'cutoff': 69.0,
#       'value': 4.943181818181818,
#       'left_node': {'feature': 0,
#        'name': 'ID',
#        'cutoff': 6.0,
#        'value': 5.048192771084337,
#        'left_node': {'feature': 3,
#         'name': 'Day of the week',
#         'cutoff': 3.0,
#         'value': 9.0,
#         'left_node': {None},
#         'right_node': {None}},
#        'right_node': {'feature': 4,
#         'name': 'Seasons',
#         'cutoff': 2.0,
#         'value': 4.626666666666667,
#         'left_node': {'feature': 4,
#          'name': 'Seasons',
#          'cutoff': 1.0,
#          'value': 6.333333333333333,
#          'left_node': {'feature': 3,
#           'name': 'Day of the week',
#           'cutoff': 4.0,
#           'value': 21.5,
#           'left_node': {None},
#           'right_node': {None}},
#          'right_node': {'feature': 3,
#           'name': 'Day of the week',
#           'cutoff': 3.0,
#           'value': 2.5416666666666665,
#           'left_node': {'feature': 3,
#            'name': 'Day of the week',
#            'cutoff': 2.0,
#            'value': 3.3333333333333335,
#            'left_node': {None},
#            'right_node': {'feature': 2,
#             'name': 'Month of absence',
#             'cutoff': 1.0,
#             'value': 3.0,
#             'left_node': {None},
#             'right_node': {None}}},
#           'right_node': {'feature': 3,
#            'name': 'Day of the week',
#            'cutoff': 4.0,
#            'value': 2.066666666666667,
#            'left_node': {'feature': 2,
#             'name': 'Month of absence',
#             'cutoff': 1.0,
#             'value': 2.0,
#             'left_node': {None},
#             'right_node': {None}},
#            'right_node': {'feature': 3,
#             'name': 'Day of the week',
#             'cutoff': 5.0,
#             'value': 2.111111111111111,
#             'left_node': {'feature': 1,
#              'name': 'Reason for absence',
#              'cutoff': 25.0,
#              'value': 2.5,
#              'left_node': {None},
#              'right_node': {None}},
#             'right_node': {None}}}}},
#         'right_node': {'feature': 4,
#          'name': 'Seasons',
#          'cutoff': 3.0,
#          'value': 3.488888888888889,
#          'left_node': {'feature': 2,
#           'name': 'Month of absence',
#           'cutoff': 4.0,
#           'value': 5.4,
#           'left_node': {'feature': 2,
#            'name': 'Month of absence',
#            'cutoff': 3.0,
#            'value': 6.2,
#            'left_node': {'feature': 1,
#             'name': 'Reason for absence',
#             'cutoff': 11.0,
#             'value': 7.0,
#             'left_node': {None},
#             'right_node': {None}},
#            'right_node': {'feature': 9,
#             'name': 'Work load Average/day ',
#             'cutoff': 246.28799999999998,
#             'value': 5.4,
#             'left_node': {None},
#             'right_node': {None}}},
#           'right_node': {'feature': 2,
#            'name': 'Month of absence',
#            'cutoff': 5.0,
#            'value': 3.8,
#            'left_node': {None},
#            'right_node': {None}}},
#          'right_node': {'feature': 2,
#           'name': 'Month of absence',
#           'cutoff': 10.0,
#           'value': 2.533333333333333,
#           'left_node': {'feature': 2,
#            'name': 'Month of absence',
#            'cutoff': 9.0,
#            'value': 2.5454545454545454,
#            'left_node': {None},
#            'right_node': {'feature': 9,
#             'name': 'Work load Average/day ',
#             'cutoff': 253.465,
#             'value': 2.5555555555555554,
#             'left_node': {None},
#             'right_node': {'feature': 3,
#              'name': 'Day of the week',
#              'cutoff': 3.0,
#              'value': 2.6,
#              'left_node': {None},
#              'right_node': {None}}}},
#           'right_node': {'feature': 2,
#            'name': 'Month of absence',
#            'cutoff': 11.0,
#            'value': 2.526315789473684,
#            'left_node': {'feature': 9,
#             'name': 'Work load Average/day ',
#             'cutoff': 268.519,
#             'value': 2.4444444444444446,
#             'left_node': {None},
#             'right_node': {'feature': 3,
#              'name': 'Day of the week',
#              'cutoff': 4.0,
#              'value': 2.2,
#              'left_node': {None},
#              'right_node': {None}}},
#            'right_node': {'feature': 10,
#             'name': 'Hit target',
#             'cutoff': 93.0,
#             'value': 2.6,
#             'left_node': {None},
#             'right_node': {'feature': 1,
#              'name': 'Reason for absence',
#              'cutoff': 23.0,
#              'value': 2.5555555555555554,
#              'left_node': {'feature': 9,
#               'name': 'Work load Average/day ',
#               'cutoff': 261.306,
#               'value': 2.5,
#               'left_node': {None},
#               'right_node': {'feature': 3,
#                'name': 'Day of the week',
#                'cutoff': 3.0,
#                'value': 2.6666666666666665,
#                'left_node': {None},
#                'right_node': {None}}},
#              'right_node': {None}}}}}}}},
#       'right_node': {'feature': 4,
#        'name': 'Seasons',
#        'cutoff': 2.0,
#        'value': 3.2,
#        'left_node': {None},
#        'right_node': {None}}}},
#     'right_node': {'feature': 12,
#      'name': 'Education',
#      'cutoff': 2.0,
#      'value': 5.851063829787234,
#      'left_node': {'feature': 0,
#       'name': 'ID',
#       'cutoff': 18.0,
#       'value': 8.375,
#       'left_node': {'feature': 4,
#        'name': 'Seasons',
#        'cutoff': 2.0,
#        'value': 8.428571428571429,
#        'left_node': {'feature': 4,
#         'name': 'Seasons',
#         'cutoff': 1.0,
#         'value': 7.333333333333333,
#         'left_node': {'feature': 2,
#          'name': 'Month of absence',
#          'cutoff': 7.0,
#          'value': 8.142857142857142,
#          'left_node': {'feature': 2,
#           'name': 'Month of absence',
#           'cutoff': 6.0,
#           'value': 6.6,
#           'left_node': {None},
#           'right_node': {None}},
#          'right_node': {None}},
#         'right_node': {None}},
#        'right_node': {'feature': 4,
#         'name': 'Seasons',
#         'cutoff': 3.0,
#         'value': 10.4,
#         'left_node': {None},
#         'right_node': {None}}},
#       'right_node': {None}},
#      'right_node': {'feature': 5,
#       'name': 'Transportation expense',
#       'cutoff': 179.0,
#       'value': 5.333333333333333,
#       'left_node': {'feature': 4,
#        'name': 'Seasons',
#        'cutoff': 2.0,
#        'value': 5.5,
#        'left_node': {'feature': 4,
#         'name': 'Seasons',
#         'cutoff': 1.0,
#         'value': 4.904761904761905,
#         'left_node': {'feature': 2,
#          'name': 'Month of absence',
#          'cutoff': 7.0,
#          'value': 3.7142857142857144,
#          'left_node': {None},
#          'right_node': {None}},
#         'right_node': {'feature': 2,
#          'name': 'Month of absence',
#          'cutoff': 1.0,
#          'value': 5.5,
#          'left_node': {'feature': 9,
#           'name': 'Work load Average/day ',
#           'cutoff': 308.593,
#           'value': 9.166666666666666,
#           'left_node': {None},
#           'right_node': {'feature': 3,
#            'name': 'Day of the week',
#            'cutoff': 2.0,
#            'value': 9.4,
#            'left_node': {None},
#            'right_node': {None}}},
#          'right_node': {'feature': 2,
#           'name': 'Month of absence',
#           'cutoff': 2.0,
#           'value': 2.75,
#           'left_node': {None},
#           'right_node': {None}}}},
#        'right_node': {'feature': 4,
#         'name': 'Seasons',
#         'cutoff': 3.0,
#         'value': 6.0,
#         'left_node': {'feature': 2,
#          'name': 'Month of absence',
#          'cutoff': 4.0,
#          'value': 2.0625,
#          'left_node': {'feature': 1,
#           'name': 'Reason for absence',
#           'cutoff': 13.0,
#           'value': 1.8333333333333333,
#           'left_node': {None},
#           'right_node': {None}},
#          'right_node': {'feature': 2,
#           'name': 'Month of absence',
#           'cutoff': 5.0,
#           'value': 2.2,
#           'left_node': {'feature': 9,
#            'name': 'Work load Average/day ',
#            'cutoff': 237.65599999999998,
#            'value': 2.142857142857143,
#            'left_node': {None},
#            'right_node': {None}},
#           'right_node': {None}}},
#         'right_node': {'feature': 2,
#          'name': 'Month of absence',
#          'cutoff': 10.0,
#          'value': 13.0,
#          'left_node': {'feature': 9,
#           'name': 'Work load Average/day ',
#           'cutoff': 253.465,
#           'value': 16.5,
#           'left_node': {None},
#           'right_node': {'feature': 3,
#            'name': 'Day of the week',
#            'cutoff': 2.0,
#            'value': 19.6,
#            'left_node': {None},
#            'right_node': {None}}},
#          'right_node': {None}}}},
#       'right_node': {'feature': 0,
#        'name': 'ID',
#        'cutoff': 1.0,
#        'value': 5.09375,
#        'left_node': {'feature': 4,
#         'name': 'Seasons',
#         'cutoff': 2.0,
#         'value': 5.5,
#         'left_node': {'feature': 4,
#          'name': 'Seasons',
#          'cutoff': 1.0,
#          'value': 5.2727272727272725,
#          'left_node': {'feature': 2,
#           'name': 'Month of absence',
#           'cutoff': 7.0,
#           'value': 5.285714285714286,
#           'left_node': {None},
#           'right_node': {None}},
#          'right_node': {None}},
#         'right_node': {'feature': 4,
#          'name': 'Seasons',
#          'cutoff': 3.0,
#          'value': 5.7272727272727275,
#          'left_node': {'feature': 3,
#           'name': 'Day of the week',
#           'cutoff': 2.0,
#           'value': 8.6,
#           'left_node': {None},
#           'right_node': {None}},
#          'right_node': {'feature': 2,
#           'name': 'Month of absence',
#           'cutoff': 11.0,
#           'value': 3.3333333333333335,
#           'left_node': {None},
#           'right_node': {None}}}},
#        'right_node': {'feature': 4,
#         'name': 'Seasons',
#         'cutoff': 3.0,
#         'value': 4.2,
#         'left_node': {'feature': 4,
#          'name': 'Seasons',
#          'cutoff': 2.0,
#          'value': 3.2857142857142856,
#          'left_node': {None},
#          'right_node': {None}},
#         'right_node': {None}}}}}},
#    'right_node': {'feature': 12,
#     'name': 'Education',
#     'cutoff': 1.0,
#     'value': 6.586206896551724,
#     'left_node': {'feature': 0,
#      'name': 'ID',
#      'cutoff': 2.0,
#      'value': 7.222222222222222,
#      'left_node': {None},
#      'right_node': {'feature': 4,
#       'name': 'Seasons',
#       'cutoff': 2.0,
#       'value': 8.0,
#       'left_node': {None},
#       'right_node': {None}}},
#     'right_node': {'feature': 4,
#      'name': 'Seasons',
#      'cutoff': 2.0,
#      'value': 6.3,
#      'left_node': {'feature': 4,
#       'name': 'Seasons',
#       'cutoff': 1.0,
#       'value': 7.636363636363637,
#       'left_node': {None},
#       'right_node': {'feature': 2,
#        'name': 'Month of absence',
#        'cutoff': 1.0,
#        'value': 8.333333333333334,
#        'left_node': {None},
#        'right_node': {'feature': 2,
#         'name': 'Month of absence',
#         'cutoff': 2.0,
#         'value': 13.2,
#         'left_node': {None},
#         'right_node': {None}}}},
#      'right_node': {'feature': 4,
#       'name': 'Seasons',
#       'cutoff': 3.0,
#       'value': 4.666666666666667,
#       'left_node': {'feature': 2,
#        'name': 'Month of absence',
#        'cutoff': 4.0,
#        'value': 4.0,
#        'left_node': {None},
#        'right_node': {'feature': 9,
#         'name': 'Work load Average/day ',
#         'cutoff': 237.65599999999998,
#         'value': 4.4,
#         'left_node': {None},
#         'right_node': {None}}},
#       'right_node': {None}}}}},
#   'right_node': {'feature': 15,
#    'name': 'Social smoker',
#    'cutoff': 0.0,
#    'value': 8.208651399491094,
#    'left_node': {'feature': 12,
#     'name': 'Education',
#     'cutoff': 2.0,
#     'value': 8.154255319148936,
#     'left_node': {'feature': 12,
#      'name': 'Education',
#      'cutoff': 1.0,
#      'value': 8.185483870967742,
#      'left_node': {'feature': 16,
#       'name': 'Pet',
#       'cutoff': 2.0,
#       'value': 8.24931506849315,
#       'left_node': {'feature': 16,
#        'name': 'Pet',
#        'cutoff': 0.0,
#        'value': 8.308823529411764,
#        'left_node': {'feature': 4,
#         'name': 'Seasons',
#         'cutoff': 2.0,
#         'value': 7.977443609022556,
#         'left_node': {'feature': 4,
#          'name': 'Seasons',
#          'cutoff': 1.0,
#          'value': 6.615942028985507,
#          'left_node': {'feature': 2,
#           'name': 'Month of absence',
#           'cutoff': 7.0,
#           'value': 6.80327868852459,
#           'left_node': {'feature': 2,
#            'name': 'Month of absence',
#            'cutoff': 6.0,
#            'value': 8.724137931034482,
#            'left_node': {None},
#            'right_node': {'feature': 10,
#             'name': 'Hit target',
#             'cutoff': 93.0,
#             'value': 9.56,
#             'left_node': {'feature': 9,
#              'name': 'Work load Average/day ',
#              'cutoff': 230.29,
#              'value': 12.222222222222221,
#              'left_node': {'feature': 3,
#               'name': 'Day of the week',
#               'cutoff': 3.0,
#               'value': 3.7142857142857144,
#               'left_node': {'feature': 1,
#                'name': 'Reason for absence',
#                'cutoff': 26.0,
#                'value': 3.4,
#                'left_node': {None},
#                'right_node': {None}},
#               'right_node': {None}},
#              'right_node': {None}},
#             'right_node': {'feature': 9,
#              'name': 'Work load Average/day ',
#              'cutoff': 239.554,
#              'value': 8.0625,
#              'left_node': {'feature': 13,
#               'name': 'Son',
#               'cutoff': 0.0,
#               'value': 7.916666666666667,
#               'left_node': {'feature': 0,
#                'name': 'ID',
#                'cutoff': 3.0,
#                'value': 3.857142857142857,
#                'left_node': {'feature': 3,
#                 'name': 'Day of the week',
#                 'cutoff': 4.0,
#                 'value': 3.1666666666666665,
#                 'left_node': {None},
#                 'right_node': {None}},
#                'right_node': {None}},
#               'right_node': {'feature': 0,
#                'name': 'ID',
#                'cutoff': 14.0,
#                'value': 13.6,
#                'left_node': {None},
#                'right_node': {None}}},
#              'right_node': {None}}}},
#           'right_node': {'feature': 2,
#            'name': 'Month of absence',
#            'cutoff': 8.0,
#            'value': 5.0625,
#            'left_node': {'feature': 10,
#             'name': 'Hit target',
#             'cutoff': 92.0,
#             'value': 3.5625,
#             'left_node': {'feature': 6,
#              'name': 'Distance from Residence to Work',
#              'cutoff': 50.0,
#              'value': 3.5714285714285716,
#              'left_node': {None},
#              'right_node': {None}},
#             'right_node': {'feature': 9,
#              'name': 'Work load Average/day ',
#              'cutoff': 249.797,
#              'value': 3.5555555555555554,
#              'left_node': {'feature': 18,
#               'name': 'Height',
#               'cutoff': 168.0,
#               'value': 4.0,
#               'left_node': {None},
#               'right_node': {None}},
#              'right_node': {None}}},
#            'right_node': {'feature': 13,
#             'name': 'Son',
#             'cutoff': 1.0,
#             'value': 6.5625,
#             'left_node': {'feature': 13,
#              'name': 'Son',
#              'cutoff': 0.0,
#              'value': 7.416666666666667,
#              'left_node': {'feature': 0,
#               'name': 'ID',
#               'cutoff': 3.0,
#               'value': 7.363636363636363,
#               'left_node': {'feature': 1,
#                'name': 'Reason for absence',
#                'cutoff': 13.0,
#                'value': 4.428571428571429,
#                'left_node': {None},
#                'right_node': {'feature': 3,
#                 'name': 'Day of the week',
#                 'cutoff': 3.0,
#                 'value': 3.0,
#                 'left_node': {None},
#                 'right_node': {None}}},
#               'right_node': {None}},
#              'right_node': {None}},
#             'right_node': {None}}}},
#          'right_node': {'feature': 13,
#           'name': 'Son',
#           'cutoff': 1.0,
#           'value': 6.467532467532467,
#           'left_node': {'feature': 13,
#            'name': 'Son',
#            'cutoff': 0.0,
#            'value': 4.610169491525424,
#            'left_node': {'feature': 18,
#             'name': 'Height',
#             'cutoff': 169.0,
#             'value': 4.5,
#             'left_node': {None},
#             'right_node': {'feature': 0,
#              'name': 'ID',
#              'cutoff': 3.0,
#              'value': 4.545454545454546,
#              'left_node': {'feature': 2,
#               'name': 'Month of absence',
#               'cutoff': 3.0,
#               'value': 3.7916666666666665,
#               'left_node': {'feature': 2,
#                'name': 'Month of absence',
#                'cutoff': 2.0,
#                'value': 3.8085106382978724,
#                'left_node': {'feature': 2,
#                 'name': 'Month of absence',
#                 'cutoff': 1.0,
#                 'value': 3.125,
#                 'left_node': {'feature': 1,
#                  'name': 'Reason for absence',
#                  'cutoff': 27.0,
#                  'value': 2.0,
#                  'left_node': {None},
#                  'right_node': {None}},
#                 'right_node': {'feature': 10,
#                  'name': 'Hit target',
#                  'cutoff': 96.0,
#                  'value': 3.3333333333333335,
#                  'left_node': {'feature': 3,
#                   'name': 'Day of the week',
#                   'cutoff': 4.0,
#                   'value': 3.3636363636363638,
#                   'left_node': {'feature': 3,
#                    'name': 'Day of the week',
#                    'cutoff': 2.0,
#                    'value': 2.8333333333333335,
#                    'left_node': {None},
#                    'right_node': {None}},
#                   'right_node': {'feature': 3,
#                    'name': 'Day of the week',
#                    'cutoff': 5.0,
#                    'value': 4.0,
#                    'left_node': {None},
#                    'right_node': {None}}},
#                  'right_node': {'feature': 10,
#                   'name': 'Hit target',
#                   'cutoff': 97.0,
#                   'value': 3.3125,
#                   'left_node': {'feature': 1,
#                    'name': 'Reason for absence',
#                    'cutoff': 13.0,
#                    'value': 3.0,
#                    'left_node': {None},
#                    'right_node': {'feature': 3,
#                     'name': 'Day of the week',
#                     'cutoff': 4.0,
#                     'value': 2.230769230769231,
#                     'left_node': {'feature': 3,
#                      'name': 'Day of the week',
#                      'cutoff': 3.0,
#                      'value': 2.142857142857143,
#                      'left_node': {None},
#                      'right_node': {None}},
#                     'right_node': {'feature': 3,
#                      'name': 'Day of the week',
#                      'cutoff': 5.0,
#                      'value': 2.3333333333333335,
#                      'left_node': {None},
#                      'right_node': {None}}}},
#                   'right_node': {None}}}},
#                'right_node': {'feature': 10,
#                 'name': 'Hit target',
#                 'cutoff': 95.0,
#                 'value': 5.266666666666667,
#                 'left_node': {None},
#                 'right_node': {'feature': 9,
#                  'name': 'Work load Average/day ',
#                  'cutoff': 222.196,
#                  'value': 3.9285714285714284,
#                  'left_node': {'feature': 1,
#                   'name': 'Reason for absence',
#                   'cutoff': 13.0,
#                   'value': 3.0833333333333335,
#                   'left_node': {None},
#                   'right_node': {'feature': 3,
#                    'name': 'Day of the week',
#                    'cutoff': 3.0,
#                    'value': 2.5,
#                    'left_node': {None},
#                    'right_node': {'feature': 3,
#                     'name': 'Day of the week',
#                     'cutoff': 4.0,
#                     'value': 2.5714285714285716,
#                     'left_node': {None},
#                     'right_node': {None}}}},
#                  'right_node': {None}}}},
#               'right_node': {None}},
#              'right_node': {'feature': 2,
#               'name': 'Month of absence',
#               'cutoff': 3.0,
#               'value': 9.714285714285714,
#               'left_node': {'feature': 2,
#                'name': 'Month of absence',
#                'cutoff': 2.0,
#                'value': 10.0,
#                'left_node': {None},
#                'right_node': {None}},
#               'right_node': {None}}}},
#            'right_node': {None}},
#           'right_node': {'feature': 0,
#            'name': 'ID',
#            'cutoff': 14.0,
#            'value': 12.555555555555555,
#            'left_node': {'feature': 3,
#             'name': 'Day of the week',
#             'cutoff': 3.0,
#             'value': 14.777777777777779,
#             'left_node': {'feature': 3,
#              'name': 'Day of the week',
#              'cutoff': 2.0,
#              'value': 16.375,
#              'left_node': {None},
#              'right_node': {'feature': 10,
#               'name': 'Hit target',
#               'cutoff': 96.0,
#               'value': 21.6,
#               'left_node': {None},
#               'right_node': {None}}},
#             'right_node': {None}},
#            'right_node': {'feature': 2,
#             'name': 'Month of absence',
#             'cutoff': 3.0,
#             'value': 10.333333333333334,
#             'left_node': {'feature': 2,
#              'name': 'Month of absence',
#              'cutoff': 2.0,
#              'value': 10.625,
#              'left_node': {None},
#              'right_node': {'feature': 9,
#               'name': 'Work load Average/day ',
#               'cutoff': 244.387,
#               'value': 13.333333333333334,
#               'left_node': {None},
#               'right_node': {'feature': 3,
#                'name': 'Day of the week',
#                'cutoff': 4.0,
#                'value': 15.2,
#                'left_node': {None},
#                'right_node': {None}}}},
#             'right_node': {None}}}}},
#         'right_node': {'feature': 4,
#          'name': 'Seasons',
#          'cutoff': 3.0,
#          'value': 9.4453125,
#          'left_node': {'feature': 2,
#           'name': 'Month of absence',
#           'cutoff': 4.0,
#           'value': 11.235294117647058,
#           'left_node': {'feature': 2,
#            'name': 'Month of absence',
#            'cutoff': 3.0,
#            'value': 12.090909090909092,
#            'left_node': {'feature': 10,
#             'name': 'Hit target',
#             'cutoff': 95.0,
#             'value': 6.25,
#             'left_node': {None},
#             'right_node': {'feature': 10,
#              'name': 'Hit target',
#              'cutoff': 98.0,
#              'value': 6.545454545454546,
#              'left_node': {'feature': 19,
#               'name': 'Body mass index',
#               'cutoff': 23.0,
#               'value': 5.166666666666667,
#               'left_node': {None},
#               'right_node': {None}},
#              'right_node': {'feature': 19,
#               'name': 'Body mass index',
#               'cutoff': 25.0,
#               'value': 8.2,
#               'left_node': {None},
#               'right_node': {None}}}},
#            'right_node': {'feature': 13,
#             'name': 'Son',
#             'cutoff': 1.0,
#             'value': 15.428571428571429,
#             'left_node': {'feature': 7,
#              'name': 'Service time',
#              'cutoff': 16.0,
#              'value': 18.09090909090909,
#              'left_node': {None},
#              'right_node': {'feature': 0,
#               'name': 'ID',
#               'cutoff': 3.0,
#               'value': 18.555555555555557,
#               'left_node': {None},
#               'right_node': {'feature': 1,
#                'name': 'Reason for absence',
#                'cutoff': 14.0,
#                'value': 25.4,
#                'left_node': {None},
#                'right_node': {None}}}},
#             'right_node': {'feature': 19,
#              'name': 'Body mass index',
#              'cutoff': 23.0,
#              'value': 12.5,
#              'left_node': {None},
#              'right_node': {'feature': 0,
#               'name': 'ID',
#               'cutoff': 13.0,
#               'value': 9.666666666666666,
#               'left_node': {None},
#               'right_node': {None}}}}},
#           'right_node': {'feature': 2,
#            'name': 'Month of absence',
#            'cutoff': 5.0,
#            'value': 10.428571428571429,
#            'left_node': {'feature': 10,
#             'name': 'Hit target',
#             'cutoff': 92.0,
#             'value': 8.294117647058824,
#             'left_node': {'feature': 7,
#              'name': 'Service time',
#              'cutoff': 14.0,
#              'value': 5.571428571428571,
#              'left_node': {None},
#              'right_node': {None}},
#             'right_node': {'feature': 9,
#              'name': 'Work load Average/day ',
#              'cutoff': 237.65599999999998,
#              'value': 10.2,
#              'left_node': {'feature': 13,
#               'name': 'Son',
#               'cutoff': 1.0,
#               'value': 11.833333333333334,
#               'left_node': {None},
#               'right_node': {None}},
#              'right_node': {None}}},
#            'right_node': {'feature': 10,
#             'name': 'Hit target',
#             'cutoff': 94.0,
#             'value': 12.444444444444445,
#             'left_node': {'feature': 13,
#              'name': 'Son',
#              'cutoff': 0.0,
#              'value': 15.1,
#              'left_node': {'feature': 0,
#               'name': 'ID',
#               'cutoff': 3.0,
#               'value': 9.666666666666666,
#               'left_node': {None},
#               'right_node': {None}},
#              'right_node': {None}},
#             'right_node': {'feature': 10,
#              'name': 'Hit target',
#              'cutoff': 95.0,
#              'value': 9.125,
#              'left_node': {'feature': 1,
#               'name': 'Reason for absence',
#               'cutoff': 26.0,
#               'value': 7.666666666666667,
#               'left_node': {None},
#               'right_node': {'feature': 13,
#                'name': 'Son',
#                'cutoff': 0.0,
#                'value': 7.6,
#                'left_node': {None},
#                'right_node': {None}}},
#              'right_node': {None}}}}},
#          'right_node': {'feature': 2,
#           'name': 'Month of absence',
#           'cutoff': 10.0,
#           'value': 7.416666666666667,
#           'left_node': {'feature': 2,
#            'name': 'Month of absence',
#            'cutoff': 9.0,
#            'value': 4.925925925925926,
#            'left_node': {'feature': 13,
#             'name': 'Son',
#             'cutoff': 1.0,
#             'value': 5.0,
#             'left_node': {'feature': 7,
#              'name': 'Service time',
#              'cutoff': 13.0,
#              'value': 4.6,
#              'left_node': {None},
#              'right_node': {None}},
#             'right_node': {None}},
#            'right_node': {'feature': 13,
#             'name': 'Son',
#             'cutoff': 1.0,
#             'value': 4.9,
#             'left_node': {'feature': 13,
#              'name': 'Son',
#              'cutoff': 0.0,
#              'value': 3.0,
#              'left_node': {'feature': 0,
#               'name': 'ID',
#               'cutoff': 3.0,
#               'value': 4.333333333333333,
#               'left_node': {'feature': 1,
#                'name': 'Reason for absence',
#                'cutoff': 23.0,
#                'value': 3.6,
#                'left_node': {None},
#                'right_node': {None}},
#               'right_node': {None}},
#              'right_node': {'feature': 0,
#               'name': 'ID',
#               'cutoff': 5.0,
#               'value': 1.4,
#               'left_node': {None},
#               'right_node': {None}}},
#             'right_node': {'feature': 0,
#              'name': 'ID',
#              'cutoff': 13.0,
#              'value': 7.222222222222222,
#              'left_node': {'feature': 9,
#               'name': 'Work load Average/day ',
#               'cutoff': 265.017,
#               'value': 7.166666666666667,
#               'left_node': {None},
#               'right_node': {'feature': 3,
#                'name': 'Day of the week',
#                'cutoff': 3.0,
#                'value': 7.0,
#                'left_node': {None},
#                'right_node': {None}}},
#              'right_node': {None}}}},
#           'right_node': {'feature': 2,
#            'name': 'Month of absence',
#            'cutoff': 11.0,
#            'value': 9.454545454545455,
#            'left_node': {'feature': 10,
#             'name': 'Hit target',
#             'cutoff': 93.0,
#             'value': 12.0,
#             'left_node': {'feature': 9,
#              'name': 'Work load Average/day ',
#              'cutoff': 268.519,
#              'value': 7.111111111111111,
#              'left_node': {None},
#              'right_node': {'feature': 6,
#               'name': 'Distance from Residence to Work',
#               'cutoff': 12.0,
#               'value': 10.6,
#               'left_node': {None},
#               'right_node': {None}}},
#             'right_node': {'feature': 13,
#              'name': 'Son',
#              'cutoff': 1.0,
#              'value': 16.0,
#              'left_node': {'feature': 13,
#               'name': 'Son',
#               'cutoff': 0.0,
#               'value': 5.285714285714286,
#               'left_node': {'feature': 0,
#                'name': 'ID',
#                'cutoff': 3.0,
#                'value': 4.833333333333333,
#                'left_node': {None},
#                'right_node': {None}},
#               'right_node': {None}},
#              'right_node': {None}}},
#            'right_node': {'feature': 10,
#             'name': 'Hit target',
#             'cutoff': 93.0,
#             'value': 5.538461538461538,
#             'left_node': {'feature': 1,
#              'name': 'Reason for absence',
#              'cutoff': 4.0,
#              'value': 2.375,
#              'left_node': {None},
#              'right_node': {'feature': 7,
#               'name': 'Service time',
#               'cutoff': 11.0,
#               'value': 1.5714285714285714,
#               'left_node': {None},
#               'right_node': {'feature': 0,
#                'name': 'ID',
#                'cutoff': 3.0,
#                'value': 1.1666666666666667,
#                'left_node': {'feature': 3,
#                 'name': 'Day of the week',
#                 'cutoff': 2.0,
#                 'value': 1.2,
#                 'left_node': {None},
#                 'right_node': {None}},
#                'right_node': {None}}}},
#             'right_node': {'feature': 9,
#              'name': 'Work load Average/day ',
#              'cutoff': 261.306,
#              'value': 10.6,
#              'left_node': {None},
#              'right_node': {None}}}}}}},
#        'right_node': {'feature': 13,
#         'name': 'Son',
#         'cutoff': 1.0,
#         'value': 9.5,
#         'left_node': {'feature': 4,
#          'name': 'Seasons',
#          'cutoff': 2.0,
#          'value': 7.228571428571429,
#          'left_node': {'feature': 4,
#           'name': 'Seasons',
#           'cutoff': 1.0,
#           'value': 3.8,
#           'left_node': {'feature': 1,
#            'name': 'Reason for absence',
#            'cutoff': 23.0,
#            'value': 2.857142857142857,
#            'left_node': {None},
#            'right_node': {'feature': 2,
#             'name': 'Month of absence',
#             'cutoff': 8.0,
#             'value': 2.6666666666666665,
#             'left_node': {None},
#             'right_node': {None}}},
#           'right_node': {None}},
#          'right_node': {'feature': 4,
#           'name': 'Seasons',
#           'cutoff': 3.0,
#           'value': 8.6,
#           'left_node': {'feature': 2,
#            'name': 'Month of absence',
#            'cutoff': 4.0,
#            'value': 7.0,
#            'left_node': {None},
#            'right_node': {'feature': 2,
#             'name': 'Month of absence',
#             'cutoff': 5.0,
#             'value': 9.666666666666666,
#             'left_node': {None},
#             'right_node': {None}}},
#           'right_node': {'feature': 2,
#            'name': 'Month of absence',
#            'cutoff': 10.0,
#            'value': 9.5,
#            'left_node': {'feature': 2,
#             'name': 'Month of absence',
#             'cutoff': 9.0,
#             'value': 10.666666666666666,
#             'left_node': {None},
#             'right_node': {'feature': 3,
#              'name': 'Day of the week',
#              'cutoff': 4.0,
#              'value': 3.5,
#              'left_node': {None},
#              'right_node': {None}}},
#            'right_node': {'feature': 2,
#             'name': 'Month of absence',
#             'cutoff': 11.0,
#             'value': 8.0,
#             'left_node': {'feature': 10,
#              'name': 'Hit target',
#              'cutoff': 93.0,
#              'value': 9.166666666666666,
#              'left_node': {None},
#              'right_node': {None}},
#             'right_node': {None}}}}},
#         'right_node': {'feature': 0,
#          'name': 'ID',
#          'cutoff': 8.0,
#          'value': 11.538461538461538,
#          'left_node': {None},
#          'right_node': {'feature': 4,
#           'name': 'Seasons',
#           'cutoff': 2.0,
#           'value': 11.842105263157896,
#           'left_node': {'feature': 4,
#            'name': 'Seasons',
#            'cutoff': 1.0,
#            'value': 8.08,
#            'left_node': {'feature': 2,
#             'name': 'Month of absence',
#             'cutoff': 7.0,
#             'value': 8.75,
#             'left_node': {'feature': 3,
#              'name': 'Day of the week',
#              'cutoff': 3.0,
#              'value': 10.0,
#              'left_node': {None},
#              'right_node': {None}},
#             'right_node': {'feature': 2,
#              'name': 'Month of absence',
#              'cutoff': 8.0,
#              'value': 7.777777777777778,
#              'left_node': {'feature': 10,
#               'name': 'Hit target',
#               'cutoff': 92.0,
#               'value': 5.75,
#               'left_node': {None},
#               'right_node': {None}},
#              'right_node': {None}}},
#            'right_node': {'feature': 3,
#             'name': 'Day of the week',
#             'cutoff': 3.0,
#             'value': 6.888888888888889,
#             'left_node': {None},
#             'right_node': {'feature': 2,
#              'name': 'Month of absence',
#              'cutoff': 1.0,
#              'value': 6.333333333333333,
#              'left_node': {None},
#              'right_node': {None}}}},
#           'right_node': {'feature': 4,
#            'name': 'Seasons',
#            'cutoff': 3.0,
#            'value': 19.076923076923077,
#            'left_node': {'feature': 2,
#             'name': 'Month of absence',
#             'cutoff': 3.0,
#             'value': 28.0,
#             'left_node': {None},
#             'right_node': {None}},
#            'right_node': {'feature': 2,
#             'name': 'Month of absence',
#             'cutoff': 10.0,
#             'value': 11.428571428571429,
#             'left_node': {'feature': 9,
#              'name': 'Work load Average/day ',
#              'cutoff': 253.465,
#              'value': 9.6,
#              'left_node': {None},
#              'right_node': {None}},
#             'right_node': {None}}}}}}},
#       'right_node': {'feature': 0,
#        'name': 'ID',
#        'cutoff': 4.0,
#        'value': 7.44,
#        'left_node': {None},
#        'right_node': {'feature': 4,
#         'name': 'Seasons',
#         'cutoff': 2.0,
#         'value': 7.75,
#         'left_node': {'feature': 4,
#          'name': 'Seasons',
#          'cutoff': 1.0,
#          'value': 10.4,
#          'left_node': {'feature': 2,
#           'name': 'Month of absence',
#           'cutoff': 7.0,
#           'value': 11.0,
#           'left_node': {None},
#           'right_node': {None}},
#          'right_node': {None}},
#         'right_node': {'feature': 4,
#          'name': 'Seasons',
#          'cutoff': 3.0,
#          'value': 5.857142857142857,
#          'left_node': {'feature': 2,
#           'name': 'Month of absence',
#           'cutoff': 4.0,
#           'value': 5.833333333333333,
#           'left_node': {None},
#           'right_node': {None}},
#          'right_node': {'feature': 2,
#           'name': 'Month of absence',
#           'cutoff': 10.0,
#           'value': 5.875,
#           'left_node': {None},
#           'right_node': {'feature': 2,
#            'name': 'Month of absence',
#            'cutoff': 11.0,
#            'value': 6.0,
#            'left_node': {None},
#            'right_node': {None}}}}}}},
#      'right_node': {'feature': 4,
#       'name': 'Seasons',
#       'cutoff': 2.0,
#       'value': 4.857142857142857,
#       'left_node': {'feature': 4,
#        'name': 'Seasons',
#        'cutoff': 1.0,
#        'value': 3.6,
#        'left_node': {None},
#        'right_node': {None}},
#       'right_node': {None}}},
#     'right_node': {None}},
#    'right_node': {'feature': 13,
#     'name': 'Son',
#     'cutoff': 0.0,
#     'value': 9.411764705882353,
#     'left_node': {'feature': 4,
#      'name': 'Seasons',
#      'cutoff': 1.0,
#      'value': 5.166666666666667,
#      'left_node': {None},
#      'right_node': {None}},
#     'right_node': {'feature': 16,
#      'name': 'Pet',
#      'cutoff': 0.0,
#      'value': 11.727272727272727,
#      'left_node': {'feature': 0,
#       'name': 'ID',
#       'cutoff': 7.0,
#       'value': 7.666666666666667,
#       'left_node': {None},
#       'right_node': {None}},
#      'right_node': {'feature': 4,
#       'name': 'Seasons',
#       'cutoff': 1.0,
#       'value': 16.6,
#       'left_node': {None},
#       'right_node': {None}}}}}},
#  'right_node': {'feature': 14,
#   'name': 'Social drinker',
#   'cutoff': 0.0,
#   'value': 0.0,
#   'left_node': {'feature': 4,
#    'name': 'Seasons',
#    'cutoff': 3.0,
#    'value': 0.0,
#    'left_node': {'feature': 15,
#     'name': 'Social smoker',
#     'cutoff': 0.0,
#     'value': 0.0,
#     'left_node': {None},
#     'right_node': {None}},
#    'right_node': {'feature': 12,
#     'name': 'Education',
#     'cutoff': 1.0,
#     'value': 0.0,
#     'left_node': {None},
#     'right_node': {None}}},
#   'right_node': {'feature': 15,
#    'name': 'Social smoker',
#    'cutoff': 0.0,
#    'value': 0.0,
#    'left_node': {'feature': 16,
#     'name': 'Pet',
#     'cutoff': 0.0,
#     'value': 0.0,
#     'left_node': {'feature': 13,
#      'name': 'Son',
#      'cutoff': 1.0,
#      'value': 0.0,
#      'left_node': {'feature': 13,
#       'name': 'Son',
#       'cutoff': 0.0,
#       'value': 0.0,
#       'left_node': {None},
#       'right_node': {'feature': 0,
#        'name': 'ID',
#        'cutoff': 5.0,
#        'value': 0.0,
#        'left_node': {'feature': 4,
#         'name': 'Seasons',
#         'cutoff': 1.0,
#         'value': 0.0,
#         'left_node': {None},
#         'right_node': {None}},
#        'right_node': {'feature': 4,
#         'name': 'Seasons',
#         'cutoff': 1.0,
#         'value': 0.0,
#         'left_node': {None},
#         'right_node': {'feature': 4,
#          'name': 'Seasons',
#          'cutoff': 3.0,
#          'value': 0.0,
#          'left_node': {None},
#          'right_node': {None}}}}},
#      'right_node': {'feature': 0,
#       'name': 'ID',
#       'cutoff': 13.0,
#       'value': 0.0,
#       'left_node': {None},
#       'right_node': {None}}},
#     'right_node': {'feature': 3,
#      'name': 'Day of the week',
#      'cutoff': 3.0,
#      'value': 0.0,
#      'left_node': {None},
#      'right_node': {None}}},
#    'right_node': {None}}}}

# %%
from sklearn.metrics import r2_score
y_pred = model.predict(X)
print(r2_score(y, y_pred))
# Out:
# 0.2069778225361676

# %%
import random

# %%
class RandomForestRegressor():
    def __init__(self, n_estimators=1000, random_state=0, bag_features=4):
        self.n_estimators = n_estimators
        np.random.RandomState = random_state
        self.bag_features = bag_features
    
    def _bootstrapX(self,X):
        bx = []
        bX = []
        for i in range(X.shape[0]):
            b = X.iloc[np.random.randint(X.shape[0]),:]
            bX.append(b)
        return pd.DataFrame(bX)
    
    def _bagX(self,X):
        #Do not select target column
        num_cols = X.shape[1]
        columns = random.sample(range(num_cols-1),self.bag_features)
        #re-append target column
        columns.append(num_cols-1)
        return X.iloc[:,columns]
    
    def fit(self, frame):
        self.trees = []
        for i in range(self.n_estimators):
            #print(i)
            bootstrapX = self._bootstrapX(frame)
            bagX = self._bagX(bootstrapX)
            #print(bagX)
            try:
                tree = DecisionTreeRegressor()
                tree.fit(bagX)
                self.trees.append(tree)
            except:
                pass
        print ('Trees generated: ' + str(len(self.trees)))
        return
    
    def predict(self, X):
        y_preds = []
        models = [dt for dt in self.trees]
        nodes = [model.get_nodes() for model in models]
        for model in models:
            y_pred = model.predict(X)
            y_preds.append(y_pred)
        mean_y_preds = np.mean(y_preds, axis=0, dtype=np.int64)
        return mean_y_preds
    
    def get_trees(self):
        return self.trees

rf = RandomForestRegressor(n_estimators=1000)
rf.fit(df)
# Out:
# Trees generated: 1000

# %%
from sklearn.metrics import r2_score
y_pred = rf.predict(X)
print(r2_score(y, y_pred))
plt.plot(y[100:200])
plt.plot(y_pred[100:200])
# Out:
# 0.24188940770426015

# %%
import sklearn.ensemble as en
rf2 = en.RandomForestRegressor(n_estimators=10)
rf2.fit(X,y)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=10,
#                       n_jobs=None, oob_score=False, random_state=None,
#                       verbose=0, warm_start=False)

# %%
from sklearn.metrics import r2_score
y_pred = rf2.predict(X)
print(r2_score(y, y_pred))
plt.plot(y[100:200])
plt.plot(y_pred[100:200])
# Out:
# 0.8036356415836118
